# %%
#!pip install fredapi

# %%
import fredapi
import qrbook_funcs as qf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# ## Problem 2

# %%
# FRED codes for US Treasury constant maturity rates
seriesnames = ['DGS1MO', 'DGS3MO', 'DGS6MO', 'DGS1', 'DGS2', 'DGS3', 'DGS5', 'DGS7', 'DGS10', 'DGS20', 'DGS30']
maturities = qf.TenorsFromNames(seriesnames)

dates, prices = qf.GetFREDMatrix(seriesnames, startdate='2018-01-02', enddate='2018-12-31')
# remove no-data periods
nobs, t = len(dates), 0
while t < nobs:
    if all(np.isnan(prices[t])):
        del prices[t]
        del dates[t]
        nobs -= 1
    else:
        t += 1

# %%
# plot the graph
x=np.arange(len(dates))
plt.plot(x,prices)
plt.title('US Treasury contant maturity rates')
plt.xlabel('Date')
plt.ylabel('Price Level')
plt.xticks(x[::10],dates[::10],rotation=45)
plt.grid(True)
plt.show();

# %%
dates[0]
# Out:
# '2018-01-02'

# %%
dates[-1]
# Out:
# '2018-12-31'

# %%
rate = pd.DataFrame(prices, index =dates, columns = seriesnames)

# %%
rate_data=rate.to_excel("C://Users//wangc//Documents//Backup T580 first//New York University//Mathematics in Finance//Risk//Week 4//rate_date.xlsx")
rate.tail()
# Out:
#             DGS1MO  DGS3MO  DGS6MO  DGS1  DGS2  DGS3  DGS5  DGS7  DGS10  \
# 2018-12-24    2.42    2.45    2.52  2.61  2.55  2.56  2.58  2.66   2.74
# 2018-12-26    2.41    2.44    2.54  2.61  2.61  2.60  2.67  2.74   2.81
# 2018-12-27    2.43    2.41    2.49  2.58  2.56  2.55  2.60  2.68   2.77
# 2018-12-28    2.39    2.40    2.48  2.57  2.52  2.50  2.56  2.63   2.72
# 2018-12-31    2.44    2.45    2.56  2.63  2.48  2.46  2.51  2.59   2.69
#
#             DGS20  DGS30
# 2018-12-24   2.88   3.00
# 2018-12-26   2.94   3.06
# 2018-12-27   2.92   3.05
# 2018-12-28   2.89   3.04
# 2018-12-31   2.87   3.02

# %%
rate_diff=rate.diff()
rate_diff.head()
# Out:
#             DGS1MO  DGS3MO  DGS6MO  DGS1  DGS2  DGS3  DGS5  DGS7  DGS10  \
# 2018-01-02     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2018-01-03    0.00   -0.03   -0.02 -0.02  0.02  0.01  0.00 -0.01  -0.02
# 2018-01-04   -0.01    0.00    0.01  0.01  0.02  0.03  0.02  0.01   0.02
# 2018-01-05   -0.01   -0.02   -0.02 -0.02  0.00  0.01  0.02  0.02   0.01
# 2018-01-08    0.03    0.06    0.02 -0.01  0.00  0.01  0.00  0.01   0.02
#
#             DGS20  DGS30
# 2018-01-02    NaN    NaN
# 2018-01-03  -0.02  -0.03
# 2018-01-04   0.00   0.01
# 2018-01-05   0.02   0.02
# 2018-01-08   0.01   0.00

# %%
covariance=rate_diff.cov()

# %%
covariance
covariance_excel=covariance.to_excel("C://Users//wangc//Documents//Backup T580 first//New York University//Mathematics in Finance//Risk//Week 4//covariance.xlsx")

# %%
(eig_vals, eig_vecs)=np.linalg.eig(covariance)

# %%
len(eig_vecs)
# Out:
# 11

# %%
print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[ 0.01489479  0.87385275  0.30560701 -0.36467858 -0.02908919  0.09277776
#   -0.0023281   0.00260462 -0.01533166  0.00801453  0.00283133]
#  [ 0.01774417  0.34451999 -0.02576804  0.65498104  0.52183188 -0.42245869
#    0.00531679  0.00943308  0.01892762  0.00825301 -0.00186901]
#  [ 0.05471416  0.22366011 -0.21395016  0.56080546 -0.29376357  0.69957708
#   -0.00833237 -0.06844549 -0.05336645 -0.04654887 -0.03508512]
#  [ 0.13041493  0.17266973 -0.24130982  0.13610005 -0.74776165 -0.54565641
#    0.0845607   0.09198987  0.055652    0.02271221  0.01759002]
#  [ 0.2897941   0.09707406 -0.50522524 -0.18051755  0.13954241  0.01097663
#   -0.74286523  0.21406474  0.00857494  0.03122599  0.02105363]
#  [ 0.3440332   0.05981383 -0.34678613 -0.16739692  0.11743142 -0.03844971
#    0.20800005 -0.79885141  0.15828615 -0.03058023 -0.0842339 ]
#  [ 0.39564972  0.00847993 -0.18057704 -0.10059084  0.12307441  0.00375903
#    0.3804569   0.25208393 -0.7007291  -0.28495611  0.07061407]
#  [ 0.42074105 -0.02400911 -0.00756714 -0.02055481  0.09007673  0.11400525
#    0.30695693  0.31816344  0.22927838  0.70456655 -0.23743762]
#  [ 0.40401216 -0.0433551   0.14888904  0.03071195  0.03507111  0.08292225
#    0.11216672  0.18633481  0.52679059 -0.36431391  0.58833857]
#  [ 0.38900628 -0.09460141  0.38250246  0.08867935 -0.07210886 -0.03785312
#   -0.18402137  0.02693183  0.10147591 -0.40877614 -0.68332679]
#  [ 0.35917781 -0.11562944  0.47463744  0.1581986  -0.13582255 -0.05341141
#   -0.33499008 -0.32023392 -0.37005132  0.34327573  0.3412752 ]]
#
# Eigenvalues
# [7.18462165e-03 1.09507460e-03 6.94438429e-04 3.85177798e-04
#  1.79248775e-04 1.48200359e-04 1.24380399e-04 5.67927658e-05
#  3.16987531e-05 2.39338874e-05 1.97458855e-05]

# %%
eig_vecs[:,1]
# Out:
# array([ 0.87385275,  0.34451999,  0.22366011,  0.17266973,  0.09707406,
#         0.05981383,  0.00847993, -0.02400911, -0.0433551 , -0.09460141,
#        -0.11562944])

# %%
eig_vals
# Out:
# array([7.18462165e-03, 1.09507460e-03, 6.94438429e-04, 3.85177798e-04,
#        1.79248775e-04, 1.48200359e-04, 1.24380399e-04, 5.67927658e-05,
#        3.16987531e-05, 2.39338874e-05, 1.97458855e-05])

# %%
# Compute the percentage of the trace from the first 3 PCs.
pct_trace=sum(eig_vals[0:3])/sum(eig_vals)
pct_trace
# Out:
# 0.9025296103123885

# %%
# Checking purpose P*D*inv(P)=A to make sure it's back to the covariance matrix
D=np.diag(eig_vals)
pd.DataFrame(np.matmul(np.matmul(eig_vecs,D),np.linalg.inv(eig_vecs)))
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000955  0.000226  0.000107  0.000105  0.000042  0.000043  0.000026
# 1   0.000226  0.000373  0.000165  0.000085  0.000049  0.000044  0.000043
# 2   0.000107  0.000165  0.000318  0.000141  0.000167  0.000158  0.000157
# 3   0.000105  0.000085  0.000141  0.000348  0.000339  0.000369  0.000384
# 4   0.000042  0.000049  0.000167  0.000339  0.000878  0.000830  0.000866
# 5   0.000043  0.000044  0.000158  0.000369  0.000830  0.000994  0.001026
# 6   0.000026  0.000043  0.000157  0.000384  0.000866  0.001026  0.001193
# 7   0.000024  0.000041  0.000161  0.000374  0.000856  0.001037  0.001208
# 8   0.000030  0.000039  0.000138  0.000339  0.000775  0.000955  0.001129
# 9   0.000020  0.000025  0.000093  0.000298  0.000674  0.000852  0.001043
# 10  0.000007  0.000024  0.000080  0.000260  0.000582  0.000756  0.000937
#
#           7         8         9         10
# 0   0.000024  0.000030  0.000020  0.000007
# 1   0.000041  0.000039  0.000025  0.000024
# 2   0.000161  0.000138  0.000093  0.000080
# 3   0.000374  0.000339  0.000298  0.000260
# 4   0.000856  0.000775  0.000674  0.000582
# 5   0.001037  0.000955  0.000852  0.000756
# 6   0.001208  0.001129  0.001043  0.000937
# 7   0.001308  0.001226  0.001164  0.001065
# 8   0.001226  0.001214  0.001168  0.001084
# 9   0.001164  0.001168  0.001221  0.001147
# 10  0.001065  0.001084  0.001147  0.001141

# %%
PCA = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11']
seriesnames = ['DGS1MO', 'DGS3MO', 'DGS6MO', 'DGS1', 'DGS2', 'DGS3', 'DGS5', 'DGS7', 'DGS10', 'DGS20', 'DGS30']
eigen_vectors=pd.DataFrame(eig_vecs, index=seriesnames, columns=PCA)

# %%
eigen_vectors
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# DGS1MO  0.014895  0.873853  0.305607 -0.364679 -0.029089  0.092778 -0.002328
# DGS3MO  0.017744  0.344520 -0.025768  0.654981  0.521832 -0.422459  0.005317
# DGS6MO  0.054714  0.223660 -0.213950  0.560805 -0.293764  0.699577 -0.008332
# DGS1    0.130415  0.172670 -0.241310  0.136100 -0.747762 -0.545656  0.084561
# DGS2    0.289794  0.097074 -0.505225 -0.180518  0.139542  0.010977 -0.742865
# DGS3    0.344033  0.059814 -0.346786 -0.167397  0.117431 -0.038450  0.208000
# DGS5    0.395650  0.008480 -0.180577 -0.100591  0.123074  0.003759  0.380457
# DGS7    0.420741 -0.024009 -0.007567 -0.020555  0.090077  0.114005  0.306957
# DGS10   0.404012 -0.043355  0.148889  0.030712  0.035071  0.082922  0.112167
# DGS20   0.389006 -0.094601  0.382502  0.088679 -0.072109 -0.037853 -0.184021
# DGS30   0.359178 -0.115629  0.474637  0.158199 -0.135823 -0.053411 -0.334990
#
#              PC8       PC9      PC10      PC11
# DGS1MO  0.002605 -0.015332  0.008015  0.002831
# DGS3MO  0.009433  0.018928  0.008253 -0.001869
# DGS6MO -0.068445 -0.053366 -0.046549 -0.035085
# DGS1    0.091990  0.055652  0.022712  0.017590
# DGS2    0.214065  0.008575  0.031226  0.021054
# DGS3   -0.798851  0.158286 -0.030580 -0.084234
# DGS5    0.252084 -0.700729 -0.284956  0.070614
# DGS7    0.318163  0.229278  0.704567 -0.237438
# DGS10   0.186335  0.526791 -0.364314  0.588339
# DGS20   0.026932  0.101476 -0.408776 -0.683327
# DGS30  -0.320234 -0.370051  0.343276  0.341275

# %%
top_3_PCA=eigen_vectors[['PC1','PC2','PC3']]

# %%
#Plot first 3 principal components 
plt.figure(figsize=(20,5))
tenornames=['1mo','3mo','6mo','1yr','2yr','3yr', '5yr','7yr','10yr','20yr','30yr']
tenornumbers=range(len(tenornames))
pc1=eigen_vectors['PC1']
pc2=eigen_vectors['PC2']
pc3=eigen_vectors['PC3']

plt.plot(tenornumbers, pc1, label='PC1')
plt.plot(tenornumbers, pc2, label='PC2')
plt.plot(tenornumbers, pc3, label='PC3')

## Configure the graph
plt.title('US Treasury constant maturity rates')
plt.xlabel('Tenor')
plt.ylabel('Level')
plt.legend()
plt.xticks(tenornumbers, tenornames)
plt.grid(True)
plt.show;

# %% [markdown]
# ## Problem 3

# %%
# This is the tenors in year
x_tenors_year=qf.TenorsFromNames(seriesnames)

# %%
# This is the observed treasury rate at 2018-12-31
y_rate=prices[-1]

# %%
# Checking the length of rate and tenors. Should be both 11.
len(y_rate), len(x_tenors_year)
# Out:
# (11, 11)

# %%
# Use the linear interpolation function from the "qrbook_funcs" It outputs three result.
# new_rate is the linear interpolation result
new_tenor, new_rate, shortrates=qf.InterpolateCurve(x_tenors_year,y_rate)

# %%
# convert the tenor unit from year to months
tenor_month=[]
for each in new_tenor:
    tenor=each * 12
    tenor_month.append(tenor)

# %%
# checking new tenor in month and new rate
#tenor_month
#new_rate

# %%
#Plot the curve

# xtick shows the 30 years point.
xtick=[1,12,24,36,48,60,72,84,96,108,120,132,144,156,168,180,192,204,216,228,240,252,264,276,288,300,312,324,336,348,360]
# Original treasury tenor point at 2018-12-31
y_rate_tenor=[1,3,6,12,24,36,60,84,120,240,360]

plt.figure(figsize=(20,6)) # change size of figure

plt.plot(tenor_month, new_rate, color='blue', label='Linear interpolation')
plt.plot(y_rate_tenor, y_rate, 'o', color='black',label='Original treasury rate at 2018-12-31')

plt.title('US Treasury contant maturity rates at 2018-12-31', size=20)
plt.xlabel('Date in months, starting from 2018-12-31', size=20)
plt.ylabel('Rate Level', size=20)
plt.xticks(xtick,rotation=0)
plt.xlim(-5,max(tenor_month)+5)
plt.legend(loc=0,prop={'size':20})
plt.grid(True)
plt.show();

# %%
from scipy.optimize import minimize

# %%
# compute nelson estimate
def nelson(b0,b1,b2,tau,time):
    res=b0+b1*tau/time*(1-math.exp(time/tau*(-1)))+b2*tau/time*(1-math.exp(time/tau*(-1))*(1+time/tau))
    return res

# %%
# compute the nelson estimate for the entire time span
def nelson_list(x):
    b0=x[0]
    b1=x[1]
    b2=x[2]
    tau=x[3]
    estimate_rate=[]
    for i in range(1,361):
        est_rate=nelson(b0,b1,b2,tau,i)
        estimate_rate.append(est_rate)
    return estimate_rate

# %%
def mad(x):
    b0=x[0]
    b1=x[1]
    b2=x[2]
    tau=x[3]
    
    # cumulate the absolute deviation
    sum_mad=0
    
    # this is the tenors in year
    x_tenors_year=qf.TenorsFromNames(seriesnames)
    # this is the observed treasury rate at 2018-12-31
    y_rate=prices[-1]
    # linear interpolation
    new_tenor, new_rate, shortrates=qf.InterpolateCurve(x_tenors_year,y_rate) 
    
    # compute all the estimated rate using formula
    estimate_rate=[]
    for i in range(1,361):
        est_rate=nelson(b0,b1,b2,tau,i)
        estimate_rate.append(est_rate)
    
    for i in range(360):
        abs_diff=abs(estimate_rate[i]-new_rate[i])
        sum_mad=sum_mad+abs_diff
    return sum_mad

# %%
x=[1,1,1,1]
mad(x)
# Out:
# 622.4549111131699

# %%
x0 = np.array([0.01,0.01,0.01,1])
res = minimize(mad, x0, method='nelder-mead', options={'xtol': 1e-8, 'disp': True, 'maxiter': 1000})
# Out:
# Optimization terminated successfully.
#          Current function value: 5.264102
#          Iterations: 446
#          Function evaluations: 757

# %%
res
# Out:
#  final_simplex: (array([[  3.63633494,  -1.22816818,  -0.3003841 , 181.23645819],
#        [  3.63633494,  -1.22816818,  -0.30038409, 181.23645818],
#        [  3.63633494,  -1.22816818,  -0.30038409, 181.23645818],
#        [  3.63633494,  -1.22816818,  -0.3003841 , 181.23645819],
#        [  3.63633494,  -1.22816818,  -0.3003841 , 181.23645819]]), array([5.26410246, 5.26410246, 5.26410246, 5.26410246, 5.26410246]))
#            fun: 5.264102458192083
#        message: 'Optimization terminated successfully.'
#           nfev: 757
#            nit: 446
#         status: 0
#        success: True
#              x: array([  3.63633494,  -1.22816818,  -0.3003841 , 181.23645819])

# %%
nelson_x=[3.63633494,  -1.22816818,  -0.3003841 , 181.23645819]

# %%
nelson_rate=nelson_list(nelson_x)

# %%
#Plot both linear interpolation and nelson rate
plt.figure(figsize=(20,10)) # change size of figure
xtick=[1,12,24,36,48,60,72,84,96,108,120,132,144,156,168,180,192,204,216,228,240,252,264,276,288,300,312,324,336,348,360]
y_rate_tenor=[1,3,6,12,24,36,60,84,120,240,360]


plt.plot(tenor_month, new_rate, color='blue',label='Linear interpolation')
plt.plot(tenor_month, nelson_rate, color='red', label='Nelson-Siegel curve')
plt.plot(y_rate_tenor, y_rate, 'o', color='black', label='Original treasury rate at 2018-12-31')

## Configure the graph
plt.title('Linear interpolation vs Nelson fitting')
plt.xlabel('Tenor (months)')
plt.ylabel('Rate (%/year)')
plt.xticks(xtick,rotation=0)
plt.xlim(-5,max(tenor_month)+5)
plt.legend(loc=0,prop={'size':20})
plt.grid(True)
plt.show;
